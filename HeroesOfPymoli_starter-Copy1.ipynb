# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import pandas as pd

# File to Load (Remember to Change These)
file_to_load = "Resources/purchase_data.csv"

# Read Purchasing File and store into Pandas data frame
purchase_data = pd.read_csv(file_to_load)

# %% [markdown]
# ## Player Count

# %% [markdown]
# * Display the total number of players

# %%
purchase_data.head()
# Out:
#    Purchase ID             SN  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
#
#                                    Item Name  Price
# 0  Extraction, Quickblade Of Trembling Hands   3.53
# 1                          Frenzied Scimitar   1.56
# 2                               Final Critic   4.88
# 3                                Blindscythe   3.27
# 4                                       Fury   1.44

# %%
total_player = {'Total Players':[len(purchase_data['SN'].unique())]}
               
total_player1 = pd.DataFrame(total_player)
total_player1
# Out:
#    Total Players
# 0            576

# %% [markdown]
# ## Purchasing Analysis (Total)

# %% [markdown]
# * Run basic calculations to obtain number of unique items, average price, etc.
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
purchase_data.describe()
# Out:
#        Purchase ID         Age     Item ID       Price
# count   780.000000  780.000000  780.000000  780.000000
# mean    389.500000   22.714103   92.114103    3.050987
# std     225.310896    6.659444   52.775943    1.169549
# min       0.000000    7.000000    0.000000    1.000000
# 25%     194.750000   20.000000   48.000000    1.980000
# 50%     389.500000   22.000000   93.000000    3.150000
# 75%     584.250000   25.000000  139.000000    4.080000
# max     779.000000   45.000000  183.000000    4.990000

# %%
purchase_data["Item Name"].head()
# Out:
# 0    Extraction, Quickblade Of Trembling Hands
# 1                            Frenzied Scimitar
# 2                                 Final Critic
# 3                                  Blindscythe
# 4                                         Fury
# Name: Item Name, dtype: object

# %%
Unique_Items = len(purchase_data["Item Name"].unique())
Unique_Items
# Out:
# 179

# %%
avg_price = round(purchase_data['Price'].mean())
avg_price
# Out:
# 3

# %%
total_purchases = round(purchase_data["Price"].sum())
total_purchases
# Out:
# 2380.0

# %%
Purchase_analysis_total= {'Unique Items':[Unique_Items],'Average Price':[avg_price],'Number of Purchases': [len(purchase_data)],
                     'Total Purchases':[total_purchases]}
Purchase_analysis_total1 =pd.DataFrame(Purchase_analysis_total)
Purchase_analysis_total1 = Purchase_analysis_total1[['Unique Items','Average Price','Number of Purchases','Total Purchases']]
Purchase_analysis_total1
# Out:
#    Unique Items  Average Price  Number of Purchases  Total Purchases
# 0           179              3                  780           2380.0

# %% [markdown]
# ## Gender Demographics

# %% [markdown]
# * Percentage and Count of Male Players
#
#
# * Percentage and Count of Female Players
#
#
# * Percentage and Count of Other / Non-Disclosed

# %%
gender = purchase_data["Gender"].value_counts()
gender1 = pd.DataFrame(gender)
gender1
# Out:
#                        Gender
# Male                      652
# Female                    113
# Other / Non-Disclosed      15

# %% [markdown]
# ## Purchasing Analysis (Gender)

# %%
male = purchase_data.groupby(['Gender']).get_group(('Male'))

male
# Out:
#      Purchase ID              SN  Age Gender  Item ID  \
# 0              0         Lisim78   20   Male      108
# 1              1     Lisovynya38   40   Male      143
# 2              2      Ithergue48   24   Male       92
# 3              3   Chamassasya86   24   Male      100
# 4              4       Iskosia90   23   Male      131
# 5              5         Yalae81   22   Male       81
# 6              6       Itheria73   36   Male      169
# 7              7     Iskjaskst81   20   Male      162
# 8              8       Undjask33   22   Male       21
# 10            10       Inguron55   23   Male       95
# 11            11    Haisrisuir60   23   Male      162
# 12            12    Saelaephos52   21   Male      116
# 13            13     Assjaskan73   22   Male        4
# 14            14     Saesrideu94   35   Male      165
# 16            16       Lisirra25   20   Male       40
# 17            17       Zontibe81   21   Male      161
# ...

# %%
female = purchase_data.groupby(['Gender']).get_group(('Female'))

female
# Out:
#      Purchase ID               SN  Age  Gender  Item ID  \
# 15            15        Lisassa64   21  Female       98
# 18            18        Reunasu60   22  Female       82
# 38            38         Reulae52   10  Female      116
# 41            41        Assosia88   20  Female        7
# 55            55        Phaelap26   25  Female       84
# 66            66     Chanastsda67   21  Female        6
# 71            71           Hari50   20  Female       29
# 72            72        Marilsa69   25  Female      178
# 76            76     Mindadaran26   13  Female       88
# 81            81         Heudai45    8  Female      174
# 84            84       Jiskjask60   21  Female       34
# 85            85       Umolrian85   32  Female       33
# 92            92     Chadistaya75   21  Female       39
# 112          112     Iskichinya81   21  Female        7
# 113          113         Phyali88   15  Female      140
# 117          117    Frichaststa61   21  Female      117
# ...

# %%
other = purchase_data.groupby(['Gender']).get_group(('Other / Non-Disclosed'))

other
# Out:
#      Purchase ID            SN  Age                 Gender  Item ID  \
# 9              9   Chanosian48   35  Other / Non-Disclosed      136
# 22            22  Siarithria38   38  Other / Non-Disclosed       24
# 82            82    Haerithp41   16  Other / Non-Disclosed      160
# 111          111      Sundim98   21  Other / Non-Disclosed       41
# 228          228   Jiskirran77   20  Other / Non-Disclosed       80
# 237          237     Idairin51   20  Other / Non-Disclosed       16
# 242          242     Eodaisu60   16  Other / Non-Disclosed       39
# 291          291     Idairin51   20  Other / Non-Disclosed       35
# 350          350     Rairith81   15  Other / Non-Disclosed       34
# 401          401      Lirtim36   15  Other / Non-Disclosed       46
# 484          484   Chanosian48   35  Other / Non-Disclosed       39
# 549          549    Maluncil97   25  Other / Non-Disclosed      146
# 629          629    Maluncil97   25  Other / Non-Disclosed      107
# ...

# %%
total_gender = len(purchase_data["SN"].value_counts())

male = purchase_data.groupby(['Gender']).get_group(('Male'))
male1 = len(male["SN"].unique())

male_percent= round((male1/total_gender)*100,2)


female = purchase_data.groupby(['Gender']).get_group(('Female'))
female1 = len(female["SN"].unique())

female_percent= round((female1/total_gender)*100,2)


other =  purchase_data.groupby(['Gender']).get_group(('Other / Non-Disclosed'))
other1 = len(other["SN"].unique())

other_percent= round((other1/total_gender)*100,2)


Gender_df = {'Total Count':[male1, female1, other1],
             'Percentage Of Players':[male_percent, female_percent,other_percent]}
Gender_df1 = pd.DataFrame(Gender_df)

Gender_df1
# Out:
#    Total Count  Percentage Of Players
# 0          484                  84.03
# 1           81                  14.06
# 2           11                   1.91

# %% [markdown]
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. by gender
#
#
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
gender_purchases = purchase_data.groupby('Gender')["SN"]

avg_by_gender_price = purchase_data.groupby('Gender')["Price"].mean()

total_purchase_value = purchase_data.groupby('Gender')["Price"].sum()

avg_per_person = (total_purchase_value / avg_by_gender_price)

gender_analysis = pd.DataFrame({"Purchase Count: " gender_purchases, "Average Purchase Price: " avg_by_gender, 
                               "Total Purchase Value: " total_purchase_value, "Avg Total Purchase Per Person: " avg_per_person})
# Out:
#   File "<ipython-input-30-fac6bc6f49be>", line 9
#     gender_analysis = pd.DataFrame({"Purchase Count: " gender_purchases, "Average Purchase Price: " avg_by_gender,
#                                                                       ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Age Demographics

# %% [markdown]
# * Establish bins for ages
#
#
# * Categorize the existing players using the age bins. Hint: use pd.cut()
#
#
# * Calculate the numbers and percentages by age group
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: round the percentage column to two decimal points
#
#
# * Display Age Demographics Table

# %%
age_bins = [0, 9.90, 14.90, 19.90, 24.90, 29.90, 34.90, 39.90, 99999]
group_names = ["<10", "10-14", "15-19", "20-24", "25-29", "30-34", "35-39", "40+"]

#database for age Demo
purchase_data["Age Demographics"]= pd.cut(purchase_data["Age"], age_bins, labels=group_names)
demographic_group =purchase_data.groupby("Age Demographics")

purchase_data.head()
# Out:
#    Purchase ID             SN  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
#
#                                    Item Name  Price Age Demographics
# 0  Extraction, Quickblade Of Trembling Hands   3.53            20-24
# 1                          Frenzied Scimitar   1.56              40+
# 2                               Final Critic   4.88            20-24
# 3                                Blindscythe   3.27            20-24
# 4                                       Fury   1.44            20-24

# %% [markdown]
# ## Purchasing Analysis (Age)

# %% [markdown]
# * Bin the purchase_data data frame by age
#
#
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %% [markdown]
# ## Top Spenders

# %% [markdown]
# * Run basic calculations to obtain the results in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the total purchase value column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %%
top_spenders = purchase_data['Item ID'].groupby(purchase_data['SN']).count()

top_spenders= pd.DataFrame(data=top_spenders)
top_spenders.columns = ['Purchase Count']

top_spenders['Average Purchase Price'] = round(purchase_data['Price'].groupby(purchase_data['SN']).mean(),2)
top_spenders['Total Purchase Value'] = purchase_data['Price'].groupby(purchase_data['SN']).sum()


top_spenders.sort_values(by=['Total Purchase Value'], ascending=False, inplace=True)

top_spenders['Average Purchase Price'] = top_spenders['Average Purchase Price'].map('${:,.2f}'.format)
top_spenders['Total Purchase Value'] = top_spenders['Total Purchase Value'].map('${:,.2f}'.format)

top_spenders.head()
# Out:
#              Purchase Count Average Purchase Price Total Purchase Value
# SN
# Lisosia93                 5                  $3.79               $18.96
# Idastidru52               4                  $3.86               $15.45
# Chamjask73                3                  $4.61               $13.83
# Iral74                    4                  $3.40               $13.62
# Iskadarya95               3                  $4.37               $13.10

# %% [markdown]
# ## Most Popular Items

# %% [markdown]
# * Retrieve the Item ID, Item Name, and Item Price columns
#
#
# * Group by Item ID and Item Name. Perform calculations to obtain purchase count, item price, and total purchase value
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the purchase count column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %%
most_items = purchase_data.groupby(['Item ID', 'Item Name','Price'])['Price'].agg(['count','sum'])
most_items.columns = ['Purchase Count', 'Total Purchase Value']

most_items.reset_index(inplace=True)
most_items.set_index(['Item ID','Item Name'] ,inplace=True)

most_items = most_items[['Purchase Count', 'Price', 'Total Purchase Value']]

most_popular_items = most_items.sort_values(by='Purchase Count', ascending=False)

most_popular_items['Price'] = most_popular_items['Price'].map('${:,.2f}'.format)
most_popular_items['Total Purchase Value'] = most_popular_items['Total Purchase Value'].map('${:,.2f}'.format)

most_popular_items.head()
# Out:
#                                                       Purchase Count  Price  \
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm              12  $4.23
# 145     Fiery Glass Crusader                                       9  $4.58
# 108     Extraction, Quickblade Of Trembling Hands                  9  $3.53
# 82      Nirvana                                                    9  $4.90
# 19      Pursuit, Cudgel of Necromancy                              8  $1.02
#
#                                                      Total Purchase Value
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm               $50.76
# 145     Fiery Glass Crusader                                       $41.22
# 108     Extraction, Quickblade Of Trembling Hands                  $31.77
# 82      Nirvana                                                    $44.10
# 19      Pursuit, Cudgel of Necromancy                               $8.16

# %% [markdown]
# ## Most Profitable Items

# %% [markdown]
# * Sort the above table by total purchase value in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the data frame

# %%
most_profitable_items = most_items.sort_values(by='Total Purchase Value', ascending=False)

most_profitable_items['Price'] = most_profitable_items['Price'].map('${:,.2f}'.format)
most_profitable_items['Total Purchase Value'] = most_profitable_items['Total Purchase Value'].map('${:,.2f}'.format)
most_profitable_items.head()
# Out:
#                                                       Purchase Count  Price  \
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm              12  $4.23
# 82      Nirvana                                                    9  $4.90
# 145     Fiery Glass Crusader                                       9  $4.58
# 92      Final Critic                                               8  $4.88
# 103     Singed Scalpel                                             8  $4.35
#
#                                                      Total Purchase Value
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm               $50.76
# 82      Nirvana                                                    $44.10
# 145     Fiery Glass Crusader                                       $41.22
# 92      Final Critic                                               $39.04
# 103     Singed Scalpel                                             $34.80
